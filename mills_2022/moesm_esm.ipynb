# %%
import pandas as pd

# %%
MOESM1_ESM = pd.read_excel('./13073_2022_1150_MOESM1_ESM.xlsx')
MOESM2_ESM= pd.read_excel('./13073_2022_1150_MOESM2_ESM.xlsx')
MOESM3_ESM= pd.read_excel('./13073_2022_1150_MOESM3_ESM.xlsx')
MOESM4_ESM= pd.read_excel('./13073_2022_1150_MOESM4_ESM.xlsx')

# %%
MOESM1_ESM.head()
# Out:
#   Sample ID1 MDR Status2 ESBL FLQ3 Phylogroup Serotype MLST4 FimH Type  \
# 0        NaN         NaN  NaN  NaN        NaN      NaN   NaN       NaN
# 1     697664     non-MDR  NaN    S         B2   O99:H6  1859     fimH5
# 2     698264     non-MDR  NaN    S         B2   O99:H6  1859     fimH5
# 3     758127     non-MDR  NaN    S         B2   O99:H6  1859     fimH5
# 4     768195     non-MDR  NaN    S         B2   O99:H6  1859     fimH5
#
#   Facility Patient ID5 Collection Date Isolate Type Primary Isolate  \
# 0      NaN         NaN             NaT          NaN             NaN
# 1      F19        P168      2019-10-03        Urine             yes
# 2      F19        P221      2019-10-12        Urine             yes
# 3      F16        P847      2020-02-10        Urine             yes
# 4      F19       P1036      2020-03-27        Urine             yes
#
#   cgMLST cluster detection      Unnamed: 14      Unnamed: 15  \
# 0              Cluster ID6  No. of Patients  No. of Isolates
# ...

# %%
MOESM2_ESM.head()
# Out:
#   Sample ID1 Primary isolates Patient ID MLST2 MDR Status3  \
# 0        NaN              NaN        NaN   NaN         NaN
# 1     766525              NaN       P627   131         MDR
# 2     747823              yes       P627   131         MDR
# 3     766509              NaN       P627   131         MDR
# 4     792831              yes       P107   410         MDR
#
#    No. of Non-Susceptibility Classes Aminoglycosides Unnamed: 7  Unnamed: 8  \
# 0                                NaN        Amikacin        NaN  Gentamicin
# 1                               11.0               S         ≤8           R
# 2                               10.0               S         ≤8           R
# 3                               10.0               S         ≤8           R
# 4                               10.0               S         ≤8           R
#
#   Unnamed: 9  ... Monobactams Unnamed: 33 Fluoroquinolones Unnamed: 35  \
# 0        NaN  ...   Aztreonam         NaN    Ciprofloxacin         NaN
# ...
