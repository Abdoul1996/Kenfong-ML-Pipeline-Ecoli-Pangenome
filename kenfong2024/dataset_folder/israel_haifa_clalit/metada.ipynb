# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the Excel file 
merge_table = pd.read_excel('/Users/abdoulabdillahi/Desktop/Research E-coli /Konfong_Ecoli_ML/Kenfong_Ecoli_ML/kenfong2024/dataset_folder/israel_haifa_clalit/Merged_Table.xlsx')
summary_sample_collection = pd.read_excel( '/Users/abdoulabdillahi/Desktop/Research E-coli /Konfong_Ecoli_ML/Kenfong_Ecoli_ML/kenfong2024/dataset_folder/israel_haifa_clalit/summary_sample_collection_mayatal_complete.xlsx')

# %%
merge_table.head()
# Out:
#   Admera Health Library ID        i7        i5   exp  Day            type  \
# 0        20084FL-03-01-268  AAGAGGCA  GGCTACTC  Maya  NaN  Clalit samples
# 1        20084FL-03-01-269  AAGAGGCA  CCTCAGAC  Maya  NaN  Clalit samples
# 2        20084FL-03-01-270  AAGAGGCA  TCCTTACG  Maya  NaN  Clalit samples
# 3        20084FL-03-01-271  AAGAGGCA  ACGCGTGG  Maya  NaN  Clalit samples
# 4        20084FL-03-01-272  AAGAGGCA  GGAACTCC  Maya  NaN  Clalit samples
#
#    pop  clone         Sample ID
# 0  NaN      1  S_MWS2_N711_S509
# 1  NaN      2  S_MWS2_N711_S510
# 2  NaN      3  S_MWS2_N711_S511
# 3  NaN      4  S_MWS2_N711_S512
# 4  NaN      5  S_MWS2_N711_S513

# %%
merge_table.shape
# Out:
# (176, 9)

# %%
merge_table.describe()
# Out:
#        Day  pop       clone
# count  0.0  0.0  176.000000
# mean   NaN  NaN   88.500000
# std    NaN  NaN   50.950957
# min    NaN  NaN    1.000000
# 25%    NaN  NaN   44.750000
# 50%    NaN  NaN   88.500000
# 75%    NaN  NaN  132.250000
# max    NaN  NaN  176.000000

# %%
merge_table['i5'].value_counts()
# Out:
# i5
# GGCTACTC    14
# CCTCAGAC    14
# TCCTTACG    14
# ACGCGTGG    14
# GGAACTCC    14
# TGGCCATG    14
# GAGAGATT    14
# CGCGGTTA    14
# GACCGCCA     8
# TAAGATGG     8
# ATTGACAT     8
# AGCCAACT     8
# TACTAGGT     8
# TCACGGTT     8
# TGTAATGA     8
# CACGTCAG     8
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

merge_table.hist()
plt.title('Histogram of Numerical Column')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
merge_table['i5'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Categorical Column')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()

# %%
merge_table.boxplot(column='clone', by='i5')
plt.title('Box Plot of Numerical Data by Categorical Groups')
plt.xlabel('Category')
plt.ylabel('Numerical Value')
plt.show()

# %%
summary_sample_collection.head()
# Out:
#    record_id sample_date  bacterial_id  count  fosfomycin  amoxi_cla  \
# 0  CL-A-0001  2021-05-11             1      1           1          3
# 1  CL-A-0002  2021-05-11             1      3           1          1
# 2  CL-A-0003  2021-05-11             1      1           1          1
# 3  CL-A-0004  2021-05-11             1      1           1          1
# 4  CL-A-0005  2021-05-11             1      1           1          1
#
#    ampicillin  amikacin  ciprofloxacin  cefuroxime  ...  gentamicin_mic  \
# 0           3         1              1           1  ...           <=1.0
# 1           3         1              1           1  ...           <=1.0
# 2           3         1              1           1  ...           <=1.0
# 3           3         1              1           1  ...           <=1.0
# 4           3         1              1           1  ...           <=1.0
#
#    meropenem_mic  nitrofurantoin_mic  piper_tazo_mic  sulfa_trim_mic  \
# ...

# %%
summary_sample_collection.describe()
# Out:
#                       sample_date  bacterial_id        count   fosfomycin  \
# count                        1000        1000.0  1000.000000  1000.000000
# mean   2021-10-23 18:38:52.800000           1.0     1.032000     1.028000
# min           2021-05-11 00:00:00           1.0     1.000000     1.000000
# 25%           2021-07-25 00:00:00           1.0     1.000000     1.000000
# 50%           2021-10-16 00:00:00           1.0     1.000000     1.000000
# 75%           2022-01-21 00:00:00           1.0     1.000000     1.000000
# max           2022-04-28 00:00:00           1.0     3.000000     3.000000
# std                           NaN           0.0     0.247057     0.235098
#
#          amoxi_cla   ampicillin     amikacin  ciprofloxacin   cefuroxime  \
# count  1000.000000  1000.000000  1000.000000     1000.00000  1000.000000
# mean      1.199000     2.069000     1.007000        1.53500     1.316000
# min       1.000000     1.000000     1.000000        1.00000     1.000000
# ...

# %%
summary_sample_collection.shape
# Out:
# (1000, 39)

# %%
summary_sample_collection.hist(figsize=(12, 12))  # Adjust the figsize to your preference
plt.title('Histogram of Numerical Column')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
summary_sample_collection['fosfomycin'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Categorical Column')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()
